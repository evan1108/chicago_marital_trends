# %%
# Dependencies and Setup

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



# File to Load (Remember to Change These)
divorce_file = "../NU_project1/Illinois_Divorce_2000_2009.csv"
m_d_state_file = "../NU_project1/M_D_State Total_1958_2009.csv"
#marriage_by_county_file = "../NU_project1/Marriages_by_County_2000_2009.csv"
divorce_2010_2016_file = "../NU_project1/IL_divorces_2010_2016.csv"
#marriages_2010_2016_file = "../NU_project1/IL_marriages_2010_2016.csv"
marriages_2000_2016_file = "../NU_project1/IL_marriages_2000_2016.csv"
smallest_marriages_2000_2016_file = "../NU_project1/Smallest_Counties_Marriages.csv"
largest_divorce_file = "../NU_project1/Largest_Divoreces.csv"
smallest_divorce_file = "../NU_project1/Smallest_Divorces.csv"



#File and store into Pandas data frame
divorce_df = pd.read_csv(divorce_file)
m_d_state_df = pd.read_csv(m_d_state_file)
#marriage_by_county_df = pd.read_csv(marriage_by_county_file)
divorce_2010_2016_df = pd.read_csv(divorce_2010_2016_file)
#marriages_2010_2016_df = pd.read_csv(marriages_2010_2016_file)
marriages_2000_2016_df = pd.read_csv(marriages_2000_2016_file)
smallest_marriages_2000_2016_df = pd.read_csv(smallest_marriages_2000_2016_file)
largest_divorce_df = pd.read_csv(largest_divorce_file)
smallest_divorce_df = pd.read_csv(smallest_divorce_file)

# %%
m_d_state_df.head()
# Out:
#    divorce_and_annulment_rate  divorces  marriage_rate  marriages  year
# 0                         3.2   39524.0            6.9    85799.0  2000
# 1                         3.0   37294.0            7.2    89469.0  2001
# 2                         3.0   37670.0            6.7    84288.0  2002
# 3                         2.8   35037.0            6.6    82889.0  2003
# 4                         2.6   33575.0            6.4    81157.0  2004

# %%
m_d_state_df.plot(kind='bar',x="year", y="marriages",color='teal')
plt.ylim(68000,90000)
plt.title("Illinois Marriages 2000 - 2019 ")
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">
# Text(0.5, 1.0, 'Illinois Marriages 2000 - 2019 ')

# %%
marriages_2000_2016_df
# Out:
#     Year    Cook Unnamed: 2 DuPage Unnamed: 4   Kane Unnamed: 6   Lake  \
# 0   2000  35,656    41.558%  5,607     6.535%  2,909     3.391%  4,603
# 1   2001  39,652    44.319%  5,754     6.431%  3,266     3.650%  5,094
# 2   2002  36,273    43.035%  5,090     6.039%  2,952     3.502%  4,781
# 3   2003  35,832    43.229%  4,973     6.000%  2,941     3.548%  4,570
# 4   2004  34,584    42.614%  4,803     5.918%  3,001     3.698%  4,478
# 5   2005  31,450    40.623%  4,842     6.254%  3,006     3.883%  4,460
# 6   2006  32,695    41.939%  4,751     6.094%  3,035     3.893%  3,995
# 7   2007  31,700    41.379%  4,918     6.420%  2,990     3.903%  4,034
# 8   2008  30,945    41.296%  4,731     6.313%  2,812     3.753%  4,151
# 9   2009  30,179    41.443%  4,665     6.406%  2,819     3.871%  3,859
# 10  2010  30,199    68.283%  4,650    10.514%  2,699     6.103%  4,063
# 11  2011  30,327    67.821%  4,803    10.741%  2,875     6.429%  4,113
# ...

# %%
marriages_2000_2016_df.plot(kind='Line',x="Year")
plt.title("Illinois Top 5 Counties Marriages for 2000 - 2019 ")
# Out:
# <img src="data:image/png;base64,..." width="664.7058637084439">
# Text(0.5, 1.0, 'Illinois Top 5 Counties Marriages for 2000 - 2019 ')

# %%
smallest_marriages_2000_2016_df
# Out:
#      County    2000    2001    2002    2003    2004    2005    2006    2007  \
# 0   Calhoun      42      31      26      30      41      34      44      32
# 1  Gallatin      51      37      35      39      39      51      38      27
# 2    Hardin      51      45      44      56      32      51      37      39
# 3      Pope      44      37      38      35      47      40      37      29
# 4     Scott      30      32      27      36      32      41      40      32
# 5       NaN  85,798  89,469  84,288  82,889  81,157  77,419  77,959  76,608
#
#      2008    2009  2010  2011  2012  2013  2014  2015  2016
# 0      25      27  27.0  27.0  27.0  20.0  24.0  22.0  26.0
# 1      49      40  36.0  25.0  38.0  32.0  40.0  37.0  27.0
# 2      47      34  52.0  42.0  41.0  35.0  34.0  38.0  28.0
# 3      44      51  48.0  59.0  41.0  37.0  40.0  34.0  33.0
# 4      34      31  27.0  23.0  25.0  28.0  24.0  15.0  25.0
# 5  74,935  72,821   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
smallest_marriages_2000_2016_df.plot(kind='bar')
plt.title("Illinois Smallest 5 Counties Marriages for 2000 - 2019 ")
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">
# Text(0.5, 1.0, 'Illinois Smallest 5 Counties Marriages for 2000 - 2019 ')

# %%
smallest_marriages_2000_2016_df

# %%
m_d_state_df.plot(kind='bar',x="year", y="divorces",color='orange')
plt.ylim(25000,40000)
plt.title("Illinois Divorces 2000 - 2019 ")
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">
# Text(0.5, 1.0, 'Illinois Divorces 2000 - 2019 ')

# %%
largest_divorce_df
# Out:
#    County   2000   2001   2002   2003   2004   2005  2006   2007   2008  \
# 0    Cook  13849  12514  13093  11676  11157  11003  9803  10273  10041
# 1  DuPage   2750   2578   2459   2510   2402   2378  2384   2356   2293
# 2    Kane   1350   1327   1439   1511   1407   1478  1474   1388   1397
# 3    Lake   2073   2029   1773   1727   1584   1793  1891   1811   1485
# 4    Will   1392   1108   1307   1410   1492   1483  1654   1716   1627
#
#     2009   2010   2011  2012  2013  2014  2015  2016
# 0  10200  10712  10519  9110  8310  8512  8834  7576
# 1   2176   2292   2310  2308  2233  2301  2355  2210
# 2   1448   1356   1503  1623  1434  1404  1413  1320
# 3   1367   1112   1072  1042  1531  1478  1871  1626
# 4   1724   1831   2014  1980  1824  1741  1427  1473

# %%
largest_divorce_df.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">

# %%
smallest_divorce_df
# Out:
#      County  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  2010  \
# 0   Calhoun    10     6    14     6    14    11    12    15     2  ...    17
# 1  Gallatin    31    29    25     5     7     6    13    14    22  ...    20
# 2    Hardin    28    16    22    24    15    10    11    27    17  ...    21
# 3      Pope    25    30    29    24    13    27    18    26    12  ...    29
# 4     Scott    20    17    21    17     7    14    17    21    25  ...    14
#
#    2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0    12    10     8     7    17     6   NaN   NaN   NaN
# 1    22    25    18    18    20    15   NaN   NaN   NaN
# 2    16    19    16    17    15    16   NaN   NaN   NaN
# 3    19    15    16    11    10    12   NaN   NaN   NaN
# 4    18    12     6     5    12    14   NaN   NaN   NaN
#
# [5 rows x 21 columns]

# %%
smallest_divorce_df.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="639.999982048484">

# %%
#divorces = m_d_state_df["divorces_and_annulments"]
#year = m_d_state_df['year']
# m_df.set_index(['year'],inplace=True)
# m_d_state_df.plot(kind='line',alpha=0.75,rot=0)
# plt.xlabel("")
# plt.show()

#C

#divorce_handle = plt.plot(divorces,color='blue')
#plt.title("Illinois Marriage & Divorce ")
#plt.ylabel("Number of Marriage or Divorce")

# %%
#plt.xlabel
#plt.setp(x_axis, rotation=90)
#plt.set_xticklabels(df.index,rotation=90)
#ax.set_xticklabels(df['year'], rotation=90)

#Across the bottom X axis YEAR
#Line graph Divorce and Annulments in Red 
#Line Graph Marriages in Blue

# Y axis can be counts
# divorces_and_annulments
# marriages

#x_axis = m_d_state_df["year"]

#newx = (x1 - xorigin)*cos(45 * pi/180)
