# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

# %%
file_marrige_pop = 'illinois_married_county.csv'
file_income = 'illinois_median_income_county.csv'

marriage_pop_df = pd.read_csv(file_marrige_pop)
marriage_pop_df = marriage_pop_df.iloc[:,0:10]
marriage_pop_df['Total Population over 15'] = marriage_pop_df['Total Population over 15'].str.replace(",","").astype(float)
marriage_pop_df['Total population'] = marriage_pop_df['Total population'].str.replace(",","").astype(float)
marriage_pop_df = marriage_pop_df.fillna('0')


races = marriage_pop_df['Race'].unique()
races = races[0:6]
years = marriage_pop_df['Year'].astype('int64').unique()
years = years[0:9]
counties = marriage_pop_df['County'].unique()
counties = counties[0:10]
top5_counties = ['Cook','DuPage','Will','Lake','Kane']
bot5_counties = ['Pope','Calhoun','Hardin','Gallatin','Scott']
marriage_pop_df.head(6)
# Out:
#    Year County                                        Race  \
# 0  2017   Cook                                       White
# 1  2017   Cook                   Black or African American
# 2  2017   Cook           American Indian and Alaska Native
# 3  2017   Cook                                       Asian
# 4  2017   Cook  Native Hawaiian and Other Pacific Islander
# 5  2017   Cook                             Some other race
#
#    Total Population over 15 Percent Married  Total population  \
# 0                 2481185.0          47.40%         3072581.0
# 1                  996533.0          23.40%         1291839.0
# 2                   11353.0          42.20%           38651.0
# 3                  309994.0          58.00%          414671.0
# 4                    1433.0          36.80%            5810.0
# 5                  380164.0          44.10%          555781.0
#
#   Percent of population  Number Married Percent Divorced  Number Divorced
# ...

# %%
tot_divorced_top5 = []
group1_top5_div = []
group2_top5_div = []
group3_top5_div = []
group4_top5_div = []
group5_top5_div = []
group6_top5_div = []

for county in top5_counties:
    for year in years:
        total_divorced_per_yr = marriage_pop_df.loc[(marriage_pop_df['Year'] == year)&(marriage_pop_df['County'] == county),'Number Divorced'].sum()
        tot_divorced_top5.append(total_divorced_per_yr)
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'White') & \
                                               (marriage_pop_df['County'] == county) & \
                                               (marriage_pop_df['Year'] == year)]).index.tolist()
        group1_top5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Black or African American')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),['Number Divorced']]).index.tolist()
        group2_top5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'American Indian and Alaska Native')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group3_top5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Asian')& \
                                               (marriage_pop_df['County'] ==county) &\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group4_top5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Native Hawaiian and Other Pacific Islander')&\
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group5_top5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Some other race')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group6_top5_div.append(marriage_pop_df.iloc[r_index[0],9])
    

tot_divorced_bot5 = []
group1_bot5_div = []
group2_bot5_div = []
group3_bot5_div = []
group4_bot5_div = []
group5_bot5_div = []
group6_bot5_div = []


for county in bot5_counties:
    for year in years:
        total_divorceded_per_yr = marriage_pop_df.loc[(marriage_pop_df['Year'] == year)&(marriage_pop_df['County'] == county),'Number Divorced'].sum()
        tot_divorced_bot5.append(total_divorced_per_yr)
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'White') & \
                                               (marriage_pop_df['County'] == county) & \
                                               (marriage_pop_df['Year'] == year)]).index.tolist()
        group1_bot5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Black or African American')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),['Number Divorced']]).index.tolist()
        group2_bot5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'American Indian and Alaska Native')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group3_bot5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Asian')& \
                                               (marriage_pop_df['County'] ==county) &\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group4_bot5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Native Hawaiian and Other Pacific Islander')&\
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group5_bot5_div.append(marriage_pop_df.iloc[r_index[0],9])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Some other race')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Divorced']).index.tolist()
        group6_bot5_div.append(marriage_pop_df.iloc[r_index[0],9])

# %%
tot_married_top5 = []
group1_top5 = []
group2_top5 = []
group3_top5 = []
group4_top5 = []
group5_top5 = []
group6_top5 = []

for county in top5_counties:
    for year in years:
        total_married_per_yr = marriage_pop_df.loc[(marriage_pop_df['Year'] == year)&(marriage_pop_df['County'] == county),'Number Married'].sum()
        tot_married_top5.append(total_married_per_yr)
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'White') & \
                                               (marriage_pop_df['County'] == county) & \
                                               (marriage_pop_df['Year'] == year)]).index.tolist()
        group1_top5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Black or African American')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),['Number Married']]).index.tolist()
        group2_top5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'American Indian and Alaska Native')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group3_top5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Asian')& \
                                               (marriage_pop_df['County'] ==county) &\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group4_top5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Native Hawaiian and Other Pacific Islander')&\
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group5_top5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Some other race')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group6_top5.append(marriage_pop_df.iloc[r_index[0],7])
    

tot_married_bot5 = []
group1_bot5 = []
group2_bot5 = []
group3_bot5 = []
group4_bot5 = []
group5_bot5 = []
group6_bot5 = []


for county in bot5_counties:
    for year in years:
        total_married_per_yr = marriage_pop_df.loc[(marriage_pop_df['Year'] == year)&(marriage_pop_df['County'] == county),'Number Married'].sum()
        tot_married_bot5.append(total_married_per_yr)
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'White') & \
                                               (marriage_pop_df['County'] == county) & \
                                               (marriage_pop_df['Year'] == year)]).index.tolist()
        group1_bot5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Black or African American')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),['Number Married']]).index.tolist()
        group2_bot5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'American Indian and Alaska Native')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group3_bot5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Asian')& \
                                               (marriage_pop_df['County'] ==county) &\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group4_bot5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Native Hawaiian and Other Pacific Islander')&\
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group5_bot5.append(marriage_pop_df.iloc[r_index[0],7])
        
        r_index = (marriage_pop_df.loc[(marriage_pop_df['Race'] == 'Some other race')& \
                                               (marriage_pop_df['County'] ==county)&\
                                               (marriage_pop_df['Year'] == year),'Number Married']).index.tolist()
        group6_bot5.append(marriage_pop_df.iloc[r_index[0],7])

# %%
result_bot5 = stats.f_oneway(group1_bot5,group2_bot5,group3_bot5,group4_bot5,group5_bot5,group6_bot5,tot_married_bot5)
result_top5 = stats.f_oneway(group1_top5,group2_top5,group3_top5,group4_top5,group5_top5,group6_top5,tot_married_top5)

result_bot5_div = stats.f_oneway(group1_bot5_div,group2_bot5_div,group3_bot5_div,group4_bot5_div,group5_bot5_div,group6_bot5_div,tot_divorced_bot5)
result_top5_div = stats.f_oneway(group1_top5_div,group2_top5_div,group3_top5_div,group4_top5_div,group5_top5_div,group6_top5_div,tot_divorced_top5)

# %%
result_df = pd.DataFrame(index=['statistic','p-value'])
result_df['Married Smallest 5 Counties'] = result_bot5
result_df['Married Largest 5 Counties'] = result_top5
result_df['Divorced Smallest 5 Counties'] = result_bot5_div
result_df['Divorced Largest 5 Counties'] = result_top5_div
result_df
# Out:
#            Married Smallest 5 Counties  Married Largest 5 Counties  \
# statistic                 1.270018e+03                3.646996e+01
# p-value                  6.500683e-214                2.679251e-33
#
#            Divorced Smallest 5 Counties  Divorced Largest 5 Counties
# statistic                  2.640987e+06                 2.503720e+01
# p-value                    0.000000e+00                 3.598933e-24
